# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/datasets/dataset/cardata.csv')
data.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
data.shape
# Out:
# (301, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
data.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
data.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
data.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
print(data['Fuel_Type'].value_counts())
print('-'*100)
print(data['Seller_Type'].value_counts())
print('-'*100)
print(data['Transmission'].value_counts())
print('-'*100)
print(data['Owner'].value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64

# %%
data[data.duplicated()]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 17    ertiga  2016           7.75          10.79       43000    Diesel
# 93  fortuner  2015          23.00          30.61       40000    Diesel
#
#    Seller_Type Transmission  Owner
# 17      Dealer       Manual      0
# 93      Dealer    Automatic      0

# %%
from datetime import datetime

# %%
data['Year'].max()
# Out:
# 2018

# %%
data['age'] = datetime.now().year - data['Year']
data.drop(['Year', 'Car_Name'], axis = 1,inplace=True)
data
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  age
# 0         Manual      0   10
# 1         Manual      0   11
# 2         Manual      0    7
# 3         Manual      0   13
# ...

# %%
data.age.describe()
# Out:
# count    301.000000
# mean      10.372093
# std        2.891554
# min        6.000000
# 25%        8.000000
# 50%       10.000000
# 75%       12.000000
# max       21.000000
# Name: age, dtype: float64

# %%
data.columns
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Fuel_Type',
#        'Seller_Type', 'Transmission', 'Owner', 'age'],
#       dtype='object')

# %%
from matplotlib import style
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
style.use('classic')
plt.figure(figsize = (20,12))
plt.suptitle('Distribution of Numeric Data', fontsize=20)

plt.subplot(231)
sns.boxplot(data=data, y = data.Selling_Price, x = data.age)

plt.subplot(232)
sns.boxplot(data=data, y = data.Present_Price, x = data.age)

plt.subplot(233)
sns.boxplot(data=data, y = data.Kms_Driven, x = data.age)

plt.subplot(234)
sns.barplot(x=data['age'], y=data['Selling_Price'])

plt.subplot(235)
sns.barplot(x=data['age'], y=data['Present_Price'])

plt.subplot(236)
sns.barplot(x=data['age'], y=data['Kms_Driven'])

plt.tight_layout(pad=3.0)
plt.show()

# %%
plt.figure(figsize = (16,10))
plt.suptitle('Distribution of Numeric Data', fontsize=20)

plt.subplot(221)
sns.histplot(x=data['Present_Price'])

plt.subplot(222)
plt.scatter(x=data['Present_Price'], y=data['Selling_Price'])
plt.xlabel('Present_Price')
plt.ylabel('Selling_Price')

plt.subplot(223)
sns.histplot(x=data['Kms_Driven'])

plt.subplot(224)
plt.scatter(x=data['Kms_Driven'], y=data['Selling_Price'])
plt.xlabel('Kms_Driven')
plt.ylabel('Selling_Price')


plt.tight_layout(pad=3)
plt.show()

# %%
cat = ['Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']

i = 0
while i < len(cat):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    sns.countplot(data=data, x=cat[i], width=.5, ax=axes[0], )
    axes[0].set_title(f"Count of {cat[i]}")
    i += 1

    sns.countplot(data=data, x=cat[i], width=.5, ax=axes[1])
    axes[1].set_title(f"Count of {cat[i]}")

    plt.tight_layout(pad=5.0)
    plt.show()
    i += 1

# %%
fig, ax = plt.subplots(1,4,figsize=(18, 6))
fig.suptitle('Categorical Data Vs Selling Price', fontsize=20)

sns.barplot(x=data['Fuel_Type'], y=data['Selling_Price'], ax=ax[0])
sns.barplot(x=data['Seller_Type'], y=data['Selling_Price'], ax=ax[1])
sns.barplot(x=data['Transmission'], y=data['Selling_Price'], ax=ax[2])
sns.barplot(x=data['Owner'], y=data['Selling_Price'], ax=ax[3])

plt.tight_layout(pad=3)
plt.show()

# %%
grouped_data = data.groupby(['Seller_Type', 'Fuel_Type'])[['Seller_Type', 'Fuel_Type']].count()

ax = grouped_data.plot(kind='bar', figsize=(10, 6))

for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10)

plt.xlabel("Seller_Type and Fuel_Type")
plt.ylabel("Count")
plt.title("Count of Seller_Type and Fuel_Type")

plt.show()

# %%
grouped_data = data.groupby(['Seller_Type', 'Transmission'])[['Seller_Type', 'Transmission']].count()

ax = grouped_data.plot(kind='bar', figsize=(10, 6))

for p in ax.patches:
    ax.annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='bottom', fontsize=10)

plt.xlabel("Seller_Type and Transmission")
plt.ylabel("Count")
plt.title("Count of Seller_Type and Transmission")

plt.show()

# %%
data.corr(numeric_only=True)
# Out:
#                Selling_Price  Present_Price  Kms_Driven     Owner       age
# Selling_Price       1.000000       0.878983    0.029187 -0.088344 -0.236141
# Present_Price       0.878983       1.000000    0.203647  0.008057  0.047584
# Kms_Driven          0.029187       0.203647    1.000000  0.089216  0.524342
# Owner              -0.088344       0.008057    0.089216  1.000000  0.182104
# age                -0.236141       0.047584    0.524342  0.182104  1.000000

# %%
data1 = data.copy()
data1
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  age
# 0         Manual      0   10
# 1         Manual      0   11
# 2         Manual      0    7
# 3         Manual      0   13
# ...

# %%
data1.replace({'Fuel_Type': {'Petrol': 2, 'Diesel': 3, 'CNG': 4}}, inplace=True)
data1.replace({'Seller_Type': {'Dealer': 2, 'Individual': 3}}, inplace=True)
data1.replace({'Transmission': {'Automatic': 2, 'Manual': 3}}, inplace=True)

# %%
data1
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 296           9.50          11.60       33988          3            2
# 297           4.00           5.90       60000          2            2
# 298           3.35          11.00       87934          2            2
# 299          11.50          12.50        9000          3            2
# 300           5.30           5.90        5464          2            2
#
#      Transmission  Owner  age
# 0               3      0   10
# 1               3      0   11
# 2               3      0    7
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Selling_Price  301 non-null    float64
#  1   Present_Price  301 non-null    float64
#  2   Kms_Driven     301 non-null    int64
#  3   Fuel_Type      301 non-null    int64
#  4   Seller_Type    301 non-null    int64
#  5   Transmission   301 non-null    int64
#  6   Owner          301 non-null    int64
#  7   age            301 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 18.9 KB

# %%
data1.describe()
# Out:
#        Selling_Price  Present_Price     Kms_Driven   Fuel_Type  Seller_Type  \
# count     301.000000     301.000000     301.000000  301.000000   301.000000
# mean        4.661296       7.628472   36947.205980    2.212625     2.352159
# std         5.082812       8.644115   38886.883882    0.425801     0.478439
# min         0.100000       0.320000     500.000000    2.000000     2.000000
# 25%         0.900000       1.200000   15000.000000    2.000000     2.000000
# 50%         3.600000       6.400000   32000.000000    2.000000     2.000000
# 75%         6.000000       9.900000   48767.000000    2.000000     3.000000
# max        35.000000      92.600000  500000.000000    4.000000     3.000000
#
#        Transmission       Owner         age
# count    301.000000  301.000000  301.000000
# mean       2.867110    0.043189   10.372093
# std        0.340021    0.247915    2.891554
# min        2.000000    0.000000    6.000000
# 25%        3.000000    0.000000    8.000000
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data1.corr(), annot=True, fmt=".0%")
plt.title('Correlation Between the Columns')
plt.show()

# %%
df1 = data1.corr()[:1].T * 100
df1.sort_values(by=['Selling_Price'], ascending=False)
# Out:
#                Selling_Price
# Selling_Price     100.000000
# Present_Price      87.898255
# Fuel_Type          50.946726
# Kms_Driven          2.918709
# Owner              -8.834410
# age               -23.614098
# Transmission      -36.712763
# Seller_Type       -55.072376

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
X1 = data1.drop('Selling_Price', axis = 1)
y1 = data1['Selling_Price']

X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size= 0.2, random_state= 0)
model1 = LinearRegression()
model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)
y_pred
# Out:
# array([ 7.15109403e+00, -4.23597596e-01,  4.29317385e+00,  8.65452674e+00,
#         1.41567775e+01,  4.90831522e+00,  3.53467957e+00,  1.44629982e+00,
#         5.38203747e+00,  4.66822329e+00,  2.25436652e+00,  1.62369073e+00,
#         5.10340136e+00,  7.63583986e+00,  8.25142614e+00,  1.42107233e+01,
#         7.39937849e+00,  4.27934188e+00, -4.57454953e-01,  2.39120792e+00,
#         5.03077854e+00,  3.81276384e+00,  6.49858604e+00,  8.14607684e+00,
#        -1.93080143e+00,  1.94357130e+00, -8.19148942e-01,  8.21481213e-01,
#         2.20224230e-03,  7.20531002e+00,  3.07786554e+00,  7.05021502e+00,
#         7.21562252e-01,  7.54652493e+00,  3.56884281e+00,  1.81884781e+00,
#         5.60660404e+00,  6.59162587e+00, -2.73350542e+00,  8.75806929e+00,
#         8.84199116e+00,  1.99052379e+01,  4.40391107e+00,  3.86694215e+00,
#         6.26329178e+00,  9.51709125e+00,  1.22523783e-01,  1.68957499e+00,
# ...

# %%
print(f'Intercept:\n {model1.intercept_}\n')
print(f'Coefficient:\n {model1.coef_}')
# Out:
# Intercept:
#  9.142084756651325
#
# Coefficient:
#  [ 4.36619980e-01 -5.48584299e-06  1.44377315e+00 -1.12076998e+00
#  -1.43830531e+00 -9.89222658e-01 -3.92595063e-01]

# %%
compair = pd.DataFrame({'Actual': y_test, 'Predict': y_pred})
compair
# Out:
#      Actual    Predict
# 223    8.25   7.151094
# 150    0.50  -0.423598
# 226    5.25   4.293174
# 296    9.50   8.654527
# 52    18.00  14.156778
# ..      ...        ...
# 137    0.65   0.289706
# 227    2.55   1.990973
# 26     4.15   3.415110
# 106    1.35   0.853054
# 92     3.51   3.584124
#
# [61 rows x 2 columns]

# %%
plt.figure(figsize=(8,8))
sns.regplot(x=y_pred, y=y_test)
plt.xlabel('Actual Price')
plt.ylabel('Pridicted Price')
plt.show()

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_absolute_error(y_test, y_pred)))
print('R2 Score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 1.000032601214477
# Mean Squared Error: 2.1885564456572273
# Root Mean Squared Error: 1.0000163004743856
# R2 Score: 0.9134181721224689

# %%
d = data1.copy()

# %%
def feature(data):
  r2_score = 0.9144342972228517
  pow = 2
  for col in data1.columns[1:]:
    new_col_name = col + '*' + col
    new_col = np.power(data1[col], 2)
    d.insert(8, new_col_name, new_col)

    x2 = d.drop('Selling_Price', axis = 1)
    y2 = d['Selling_Price']

    X_train, X_test, y_train, y_test = train_test_split(x2, y2, test_size= 0.2, random_state= 0)
    model2 = LinearRegression()
    model2.fit(X_train, y_train)
    y_pred = model2.predict(X_test)

    new_r2_score = metrics.r2_score(y_test, y_pred)
    if r2_score > new_r2_score:
      d.drop(new_col_name, axis = 1, inplace= True)
    else:
      r2_score = new_r2_score
  print(r2_score)

# %%
score = feature(data1)
# Out:
# 0.9311515333497858

# %% [markdown]
# 2% improve!

# %%
df = d.copy()

# %%
def feature2(data):
  r2_score = 0.9311515333497858
  for col1 in d.columns[1:]:
    for col2 in d.columns[1:]:
      new_col_name = col1 + '*' + col2
      new_col_name_inv = col2 + '*' + col1
      if new_col_name_inv in df.columns:
        continue
      new_col = d[col1]*d[col2]
      df.insert(8, new_col_name, new_col)

      X3 = df.drop('Selling_Price', axis = 1)
      y3 = df['Selling_Price']

      X_train, X_test, y_train, y_test = train_test_split(X3, y3, test_size= 0.2, random_state= 0)
      model3 = LinearRegression()
      model3.fit(X_train, y_train)
      y_pred = model3.predict(X_test)

      new_r2_score = metrics.r2_score(y_test, y_pred)
      if r2_score > new_r2_score:
        df.drop(new_col_name, axis = 1, inplace= True)
      else:
        r2_score = new_r2_score
  print(r2_score)

# %%
score = feature2(d)
# Out:
# 0.9744004373891616

# %% [markdown]
# 4% improve!

# %% [markdown]
# Use Cross Validation

# %%
df.shape
# Out:
# (301, 40)

# %%
dfcorr = df.corr()[:1].T * 100
dfcorr.sort_values(by=['Selling_Price'], ascending=False)
# Out:
#                                            Selling_Price
# Selling_Price                                 100.000000
# Present_Price                                  87.898255
# Present_Price*Seller_Type                      85.822661
# Present_Price*age                              69.707210
# Present_Price*Present_Price                    61.941781
# Present_Price*Kms_Driven                       54.618265
# age*Present_Price*Present_Price                52.499302
# Fuel_Type                                      50.946726
# Fuel_Type*Fuel_Type                            49.333728
# Present_Price*Present_Price*Kms_Driven         48.418851
# Fuel_Type*Fuel_Type*Fuel_Type                  46.934308
# Present_Price*Present_Price*Present_Price      44.270819
# Present_Price*Kms_Driven*Kms_Driven            34.446692
# age*Fuel_Type*Fuel_Type                        28.077094
# Kms_Driven*Fuel_Type                           13.702728
# ...

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
X4 = df.drop('Selling_Price', axis = 1)
y4 = df['Selling_Price']
X_train, X_test, y_train, y_test = train_test_split(X4, y4, test_size= 0.2, random_state= 0)
model4 = LinearRegression()
model4.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
K = KFold(n_splits=10)
result = cross_val_score(model4, X4, y4, cv= K, n_jobs= -1)
print(result)
# Out:
# [  0.8042537    0.94342877  -1.83254563   0.96522454   0.07044223
#  -70.21890313  -8.05340288   0.87201531   0.91238638   0.93283815]

# %%
len(df)/11
# Out:
# 27.363636363636363

# %%
dfNew1 = df.iloc[:138]
dfNew2 = df.iloc[165:]
df_combined = pd.concat([dfNew1, dfNew2], ignore_index=True)
df_combined
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 269           9.50          11.60       33988          3            2
# 270           4.00           5.90       60000          2            2
# 271           3.35          11.00       87934          2            2
# 272          11.50          12.50        9000          3            2
# 273           5.30           5.90        5464          2            2
#
#      Transmission  Owner  age  Present_Price*Present_Price*Kms_Driven  \
# ...

# %%
X5 = df_combined.drop('Selling_Price', axis = 1)
y5 = df_combined['Selling_Price']

X_train, X_test, y_train, y_test = train_test_split(X5, y5, test_size= 0.2, random_state=0)
model5 = LinearRegression()
model5.fit(X_train, y_train)
y_pred = model5.predict(X_test)

# %%
print(f'Intercept:\n {model5.intercept_}\n')
print(f'Coefficient:\n {model5.coef_}')
# Out:
# Intercept:
#  1.6205393271244124
#
# Coefficient:
#  [ 8.87600119e-01 -2.38605617e-05  6.58577946e-01 -6.30354761e-02
#  -1.38112931e+00  4.07117227e-01 -9.25339355e-03 -4.31024853e-08
#  -1.25827033e-01 -5.60677237e-05 -5.72704603e-01 -2.17546557e-01
#  -9.34104599e-04  5.80917536e-02 -5.60613970e-05  5.04810109e-02
#  -1.25827031e-01 -7.53091201e-11  9.12396658e-02  1.00817809e-01
#  -3.15175966e-01 -7.66092382e-11 -4.28766901e-01  4.63375270e-01
#  -3.84943527e-01  4.63375271e-01 -2.37513592e-05  2.62031166e-05
#   1.38764400e-05  5.50562826e-05  3.11035448e-11 -2.88525667e-02
#  -2.17546548e-01  1.46687150e-02 -4.53443357e-06  4.07117231e-01
#   1.85501003e+00  2.83787523e-10  1.15198040e-02]

# %%
compair = pd.DataFrame({'Actual': y_test, 'Predict': y_pred})
compair
# Out:
#      Actual    Predict
# 220    5.95   5.977631
# 260    5.75   5.423478
# 204    9.25   7.510269
# 111    1.15   1.024343
# 179    5.75   5.905878
# 161    0.25   0.430570
# 89     4.75   4.082523
# 231    8.40   8.968787
# 55     3.60   4.254042
# 200    2.55   2.028469
# 213    5.35   5.830793
# 245    7.50   6.594911
# 212    2.00   2.699347
# 126    0.90   0.661312
# 97    17.00  15.516677
# 15     7.75   8.547799
# 8      8.75   7.832274
# 152    0.31  -2.317294
# 59    19.99  23.445047
# 178    5.25   4.481533
# 45     7.50   8.355480
# 116    1.10   0.839044
# 210   11.25   8.977937
# 160    0.25   0.364288
# 63    23.50  25.281006
# 7      6.50   6.905467
# 92     3.51   0.951379
# 237    4.00   4.523766
# 171    0.15   0.203675
# 81     4.75   6.365551
# 144    0.40   0.399396
# 118    1.10   0.909675
# 103    1.45   1.140480
# 233    9.15   9.402745
# 73     2.65   2.698568
# 137    0.65   0.552713
# 232    3.90   4.286634
# 83    12.50   9.651778
# 64    33.00  36.643987
# ...

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_absolute_error(y_test, y_pred)))
print('R2 Score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.8133278715185549
# Mean Squared Error: 1.4351603528754378
# Root Mean Squared Error: 0.9018469224422485
# R2 Score: 0.9611263322918567

# %%
plt.figure(figsize= (15,10))
sns.regplot(x=y_pred, y=y_test)
plt.xlabel ('Predicted Price')
plt.ylabel ('Actual Price')
plt.title('Actual VS Predicted price')
plt.show()

# %%
plt.figure(figsize= (20,10))
a= X_test.Present_Price
b= y_test
c= X_test.Present_Price
d= y_pred
plt.scatter (a, b, color='blue', label= 'real')
plt.scatter (c, d, color='orange', label= 'Prediction')
plt.legend(fontsize=60, loc='upper left')
plt.grid()
plt.show()

# %%
X_test.insert (0, 'y_test', y_test)
X_test.insert (0, 'y_pred', y_pred)

# %%
dftest= X_test.sort_values(by=['Present_Price'])

# %%
plt.figure(figsize= (15,10))
a= dftest.Present_Price
b= dftest.y_test
c=dftest.Present_Price
d= dftest.y_pred
plt.scatter (a, b, color='blue', label= 'real')
plt.plot (c, d, color='orange', label= 'Prediction')
plt.legend(fontsize=60, loc='upper left')
plt.xlabel ('Present_Price')
plt.ylabel ('Selling_Price')

plt.show()

# %%
from sklearn import preprocessing

# %%
scaler=preprocessing.MinMaxScaler(feature_range=(0,1))
normal= scaler.fit_transform(df_combined)
df_normal= pd.DataFrame (normal, columns=[df_combined])
df_normal.head()
# Out:
#   Selling_Price Present_Price Kms_Driven Fuel_Type Seller_Type Transmission  \
# 0      0.093123      0.057109   0.053053       0.0         0.0          1.0
# 1      0.133238      0.099913   0.085085       0.5         0.0          1.0
# 2      0.204871      0.103273   0.012813       0.0         0.0          1.0
# 3      0.078797      0.041504   0.009409       0.0         0.0          1.0
# 4      0.128940      0.070980   0.083984       0.5         0.0          1.0
#
#   Owner       age Present_Price*Present_Price*Kms_Driven  \
# 0   0.0  0.266667                               0.001261
# 1   0.0  0.333333                               0.005851
# 2   0.0  0.066667                               0.001001
# 3   0.0  0.466667                               0.000134
# 4   0.0  0.266667                               0.002995
#
#   Owner*Owner*Fuel_Type*Fuel_Type  ...  \
# 0                             0.0  ...
# 1                             0.0  ...
# 2                             0.0  ...
# ...

# %%
X6 = df_normal.drop (['Selling_Price'], axis=1)
y6 =df_normal['Selling_Price']
# Out:
# <ipython-input-61-d061db484644>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   X6 = df_normal.drop (['Selling_Price'], axis=1)

# %%
X_train, X_test, y_train,y_test= train_test_split(X6, y6, test_size= 0.20, random_state=0)
model16=LinearRegression()
model16.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred= model16.predict(X_test)
print (model16.intercept_)
print (model16.coef_)
# Out:
# [0.04138836]
# [[ 2.34690938e+00 -1.48819093e-01  4.41507258e+11  6.52466939e+12
#   -3.78945574e-02  3.63895999e+11  7.44672571e-02 -6.99361361e-01
#    2.95293488e+10 -7.28503804e+09 -4.61165064e-01  1.30597435e+11
#   -3.19937190e+00  4.32683687e-01  2.42834601e+09  2.36098004e+00
#    2.21759887e+11 -1.05303958e+00  1.23803275e-01  1.50073127e-01
#   -6.52466939e+12 -5.98023144e-01  4.75469355e+11 -4.08192034e+11
#   -6.48815169e-01 -4.42943497e+11  3.04824768e+11 -1.01608256e+11
#    2.11609645e-01  1.17654311e+00  4.92462320e-01 -1.05030525e+00
#   -4.35324784e+10  6.77065695e-02 -9.58050196e-01 -4.94744795e+10
#   -9.16976612e+11  1.50515154e+00  2.78575487e+00]]

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_absolute_error(y_test, y_pred)))
print('R2 Score:', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 0.02392098520959837
# Mean Squared Error: 0.0011521059629586653
# Root Mean Squared Error: 0.15466410446382953
# R2 Score: 0.9619899563714019

# %% [markdown]
# ####predict sample
# #present price=11.23
# #kms_driven=42000
# #Fuel_type=petrol
# #Sealer_type=Dealer
# #Transmission= Manual
# #Owner=1
# #Age=10
# #price=????

# %%
df_combined.columns.to_list()
# Out:
# ['Selling_Price',
#  'Present_Price',
#  'Kms_Driven',
#  'Fuel_Type',
#  'Seller_Type',
#  'Transmission',
#  'Owner',
#  'age',
#  'Present_Price*Present_Price*Kms_Driven',
#  'Owner*Owner*Fuel_Type*Fuel_Type',
#  'Owner*Owner*age',
#  'Owner*Owner*Seller_Type',
#  'Owner*Owner*Present_Price',
#  'age*Present_Price*Present_Price',
#  'age*Fuel_Type*Fuel_Type',
#  'age*Owner',
#  'Owner*Present_Price*Present_Price',
#  'Owner*Fuel_Type*Fuel_Type',
#  'Transmission*Kms_Driven*Kms_Driven',
#  'Transmission*age',
#  'Seller_Type*age',
#  'Seller_Type*Seller_Type',
#  'Fuel_Type*Kms_Driven*Kms_Driven',
#  'Fuel_Type*Fuel_Type*Fuel_Type',
#  'Fuel_Type*Owner*Owner',
#  'Fuel_Type*age',
#  'Fuel_Type*Owner',
#  'Kms_Driven*Owner*Owner',
#  'Kms_Driven*Owner',
#  'Kms_Driven*Fuel_Type',
#  'Present_Price*Present_Price*Present_Price',
#  'Present_Price*Kms_Driven*Kms_Driven',
#  'Present_Price*age',
#  'Present_Price*Owner',
#  'Present_Price*Seller_Type',
#  'Present_Price*Kms_Driven',
# ...

# %%
Selling_Price=11
Present_Price=11.23
Kms_Driven=42000
Fuel_Type=2
Seller_Type=2
Transmission= 2
Owner=1
age= 10
Owner2 = Owner ** 2
Fuel_Type2 = Fuel_Type ** 2
Kms_Driven2 = Kms_Driven ** 2
Present_Price2 = Present_Price ** 2
sample_pred= pd.DataFrame ({'Selling_Price': [Selling_Price],
  'Present_Price': [Present_Price],
  'Kms_Driven': [Kms_Driven],
  'Fuel_Type': [Fuel_Type],
  'Seller_Type': [Seller_Type],
  'Transmission': [Transmission],
  'Owner': [Owner],
  'age': [age],
  'Present_Price*Present_Price*Kms_Driven': [Present_Price2*Kms_Driven],
  'Owner*Owner*Fuel_Type*Fuel_Type': [Fuel_Type*Fuel_Type*Owner2],
  'Owner*Owner*Fuel_Type*Fuel_Type': [Owner2*Fuel_Type2],

  'Owner*Owner*Seller_Type': [Owner2*Seller_Type],
  'Owner*Owner*Present_Price': [Owner2*Present_Price],
  'age*Present_Price*Present_Price': [Present_Price2*age],
  'age*Fuel_Type*Fuel_Type': [Fuel_Type2*age],
  'age*Owner': [age*Owner],
  'Owner*Present_Price*Present_Price': [Present_Price2*Owner],
  'Owner*Fuel_Type*Fuel_Type': [Fuel_Type2*Owner],
  'Owner*Owner*age' : [Owner2*age],
  'Transmission*Kms_Driven*Kms_Driven': [Transmission*Kms_Driven2],
  'Transmission*age': [age*Transmission],
  'Seller_Type*age': [Seller_Type*age],
  'Seller_Type*Seller_Type': [Seller_Type*Seller_Type],
  'Fuel_Type*Kms_Driven*Kms_Driven': [Kms_Driven2*Fuel_Type],
  'Fuel_Type*Fuel_Type*Fuel_Type': [Fuel_Type*Fuel_Type*Fuel_Type],
  'Fuel_Type*Owner*Owner': [Owner2*Fuel_Type],
  'Fuel_Type*age': [age*Fuel_Type],
  'Fuel_Type*Owner': [Owner*Fuel_Type],
  'Kms_Driven*Owner*Owner': [Owner2*Kms_Driven],
  'Kms_Driven*Owner': [Owner*Kms_Driven],
  'Kms_Driven*Fuel_Type': [Fuel_Type*Kms_Driven],
  'Present_Price*Present_Price*Present_Price': [Present_Price2*Present_Price],
  'Present_Price*Kms_Driven*Kms_Driven': [Present_Price*Kms_Driven2],
  'Present_Price*age': [Present_Price*age],
  'Present_Price*Owner': [Present_Price*Owner],
  'Present_Price*Seller_Type': [Seller_Type*Present_Price],
  'Present_Price*Kms_Driven': [Present_Price*Kms_Driven],
  'Owner*Owner': [Owner*Owner],
  'Fuel_Type*Fuel_Type': [Fuel_Type2],
  'Kms_Driven*Kms_Driven': [Kms_Driven2],
  'Present_Price*Present_Price': [Present_Price2]})
len(sample_pred.columns)
# Out:
# 40

# %%
DF = pd.concat([df_combined, sample_pred])
DF
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0             3.35           5.59       27000          2            2
# 1             4.75           9.54       43000          3            2
# 2             7.25           9.85        6900          2            2
# 3             2.85           4.15        5200          2            2
# 4             4.60           6.87       42450          3            2
# ..             ...            ...         ...        ...          ...
# 270           4.00           5.90       60000          2            2
# 271           3.35          11.00       87934          2            2
# 272          11.50          12.50        9000          3            2
# 273           5.30           5.90        5464          2            2
# 0            11.00          11.23       42000          2            2
#
#      Transmission  Owner  age  Present_Price*Present_Price*Kms_Driven  \
# ...

# %%
X= DF.drop (['Selling_Price'], axis=1)[:274]
y = DF['Selling_Price'][:274]
x_test=  DF.drop (['Selling_Price'], axis=1)[274:]
yt = DF['Selling_Price'][274:]
model7 = LinearRegression()
model7.fit(X, y)
# Out:
# LinearRegression()

# %%
y.shape
# Out:
# (274,)

# %%
y_pred=model7.predict(x_test)
y_pred
# Out:
# array([6.38257152])

# %%
style.use('classic')
plt.figure(figsize = (20,12))
plt.suptitle('Predict Value in Data', fontsize=20)


plt.subplot(231)
sns.scatterplot(y = y, x = X.Kms_Driven)
sns.scatterplot(y = y_pred, x = x_test.Kms_Driven, color = 'red', s = 100)

plt.subplot(232)
sns.scatterplot(y = y, x = X.Present_Price)
sns.scatterplot(y = y_pred, x = x_test.Present_Price, color = 'red', s = 100)

plt.subplot(233)
sns.scatterplot(y = y, x = X.Fuel_Type)
sns.scatterplot(y = y_pred, x = x_test.Fuel_Type, color = 'red', s = 100)

plt.subplot(234)
sns.scatterplot(y=y, x=X.Seller_Type)
sns.scatterplot(y = y_pred, x = x_test.Seller_Type, color = 'red', s = 100)

plt.subplot(235)
sns.scatterplot(y=y, x=X.Transmission)
sns.scatterplot(y = y_pred, x = x_test.Transmission, color = 'red', s = 100)

plt.subplot(236)
sns.scatterplot(y=y, x=X.age)
sns.scatterplot(y = y_pred, x = x_test.age, color = 'red', s = 100)

plt.tight_layout(pad=3.0)
plt.show()
